# %% [markdown]
# <a href="https://colab.research.google.com/github/soheldatta17/Football-Match-Prediction/blob/main/prediction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
matches = pd.read_csv("/content/matches.csv", index_col=0)

# %%
matches.head()
# Out:
#          date   time            comp        round  day venue result   gf   ga  \
# 1  2021-08-15  16:30  Premier League  Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00  Premier League  Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30  Premier League  Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00  Premier League  Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00  Premier League  Matchweek 5  Sat  Home      D  0.0  0.0
#
#          opponent  ...  match report  notes    sh   sot  dist   fk   pk pkatt  \
# 1       Tottenham  ...  Match Report    NaN  18.0   4.0  16.9  1.0  0.0   0.0
# 2    Norwich City  ...  Match Report    NaN  16.0   4.0  17.3  1.0  0.0   0.0
# 3         Arsenal  ...  Match Report    NaN  25.0  10.0  14.3  0.0  0.0   0.0
# 4  Leicester City  ...  Match Report    NaN  25.0   8.0  14.0  0.0  0.0   0.0
# 6     Southampton  ...  Match Report    NaN  16.0   1.0  15.7  1.0  0.0   0.0
#
#    season             team
# ...

# %%
matches.shape
# Out:
# (1389, 27)

# %%
# 2 seasons * 20 squads * 38 matches

2 * 20 * 38
# Out:
# 1520

# %%
# Missing Liverpool 2021-2022
matches["team"].value_counts()
# Out:
# team
# Southampton                 72
# Brighton and Hove Albion    72
# Manchester United           72
# West Ham United             72
# Newcastle United            72
# Burnley                     71
# Leeds United                71
# Crystal Palace              71
# Manchester City             71
# Wolverhampton Wanderers     71
# Tottenham Hotspur           71
# Arsenal                     71
# Leicester City              70
# Chelsea                     70
# Aston Villa                 70
# Everton                     70
# Liverpool                   38
# Fulham                      38
# West Bromwich Albion        38
# Sheffield United            38
# Brentford                   34
# Watford                     33
# Norwich City                33
# Name: count, dtype: int64

# %%
matches[matches["team"] == "Liverpool"].sort_values("date")
# Out:
#           date   time            comp         round  day venue result   gf  \
# 1   2020-09-12  17:30  Premier League   Matchweek 1  Sat  Home      W  4.0
# 2   2020-09-20  16:30  Premier League   Matchweek 2  Sun  Away      W  2.0
# 4   2020-09-28  20:00  Premier League   Matchweek 3  Mon  Home      W  3.0
# 6   2020-10-04  19:15  Premier League   Matchweek 4  Sun  Away      L  2.0
# 7   2020-10-17  12:30  Premier League   Matchweek 5  Sat  Away      D  2.0
# 9   2020-10-24  20:00  Premier League   Matchweek 6  Sat  Home      W  2.0
# 11  2020-10-31  17:30  Premier League   Matchweek 7  Sat  Home      W  2.0
# 13  2020-11-08  16:30  Premier League   Matchweek 8  Sun  Away      D  1.0
# 14  2020-11-22  19:15  Premier League   Matchweek 9  Sun  Home      W  3.0
# 16  2020-11-28  12:30  Premier League  Matchweek 10  Sat  Away      D  1.0
# 18  2020-12-06  19:15  Premier League  Matchweek 11  Sun  Home      W  4.0
# ...

# %%
matches["round"].value_counts()
# Out:
# round
# Matchweek 1     39
# Matchweek 16    39
# Matchweek 34    39
# Matchweek 32    39
# Matchweek 31    39
# Matchweek 29    39
# Matchweek 28    39
# Matchweek 26    39
# Matchweek 25    39
# Matchweek 24    39
# Matchweek 23    39
# Matchweek 2     39
# Matchweek 19    39
# Matchweek 17    39
# Matchweek 20    39
# Matchweek 15    39
# Matchweek 5     39
# Matchweek 3     39
# Matchweek 13    39
# Matchweek 12    39
# Matchweek 4     39
# Matchweek 11    39
# Matchweek 10    39
# Matchweek 9     39
# Matchweek 8     39
# Matchweek 14    39
# Matchweek 7     39
# Matchweek 6     39
# Matchweek 30    37
# Matchweek 27    37
# Matchweek 22    37
# Matchweek 21    37
# Matchweek 18    37
# Matchweek 33    32
# Matchweek 35    20
# Matchweek 36    20
# Matchweek 37    20
# Matchweek 38    20
# Name: count, dtype: int64

# %%
matches.dtypes
# Out:
# date             object
# time             object
# comp             object
# round            object
# day              object
# venue            object
# result           object
# gf              float64
# ga              float64
# opponent         object
# xg              float64
# xga             float64
# poss            float64
# attendance      float64
# captain          object
# formation        object
# referee          object
# match report     object
# notes           float64
# sh              float64
# sot             float64
# dist            float64
# fk              float64
# pk              float64
# pkatt           float64
# season            int64
# team             object
# dtype: object

# %%
del matches["comp"]

# %%
del matches["notes"]

# %%
matches["date"] = pd.to_datetime(matches["date"])

# %%
matches["target"] = (matches["result"] == "W").astype("int")

# %%
matches
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 38 2021-05-02  19:15  Matchweek 34  Sun  Away      L  0.0  4.0
# 39 2021-05-08  15:00  Matchweek 35  Sat  Home      L  0.0  2.0
# 40 2021-05-16  19:00  Matchweek 36  Sun  Away      W  1.0  0.0
# 41 2021-05-19  18:00  Matchweek 37  Wed  Away      L  0.0  1.0
# 42 2021-05-23  16:00  Matchweek 38  Sun  Home      W  1.0  0.0
#
#           opponent   xg  ...  match report    sh   sot  dist   fk   pk pkatt  \
# 1        Tottenham  1.9  ...  Match Report  18.0   4.0  16.9  1.0  0.0   0.0
# ...

# %%
matches["venue_code"] = matches["venue"].astype("category").cat.codes

# %%
matches["opp_code"] = matches["opponent"].astype("category").cat.codes

# %%
matches["hour"] = matches["time"].str.replace(":.+", "", regex=True).astype("int")

# %%
matches["day_code"] = matches["date"].dt.dayofweek

# %%
matches.head(10)
# Out:
#          date   time         round  day venue result   gf   ga  \
# 1  2021-08-15  16:30   Matchweek 1  Sun  Away      L  0.0  1.0
# 2  2021-08-21  15:00   Matchweek 2  Sat  Home      W  5.0  0.0
# 3  2021-08-28  12:30   Matchweek 3  Sat  Home      W  5.0  0.0
# 4  2021-09-11  15:00   Matchweek 4  Sat  Away      W  1.0  0.0
# 6  2021-09-18  15:00   Matchweek 5  Sat  Home      D  0.0  0.0
# 8  2021-09-25  12:30   Matchweek 6  Sat  Away      W  1.0  0.0
# 10 2021-10-03  16:30   Matchweek 7  Sun  Away      D  2.0  2.0
# 11 2021-10-16  15:00   Matchweek 8  Sat  Home      W  2.0  0.0
# 13 2021-10-23  17:30   Matchweek 9  Sat  Away      W  4.0  1.0
# 15 2021-10-30  15:00  Matchweek 10  Sat  Home      L  0.0  2.0
#
#           opponent   xg  ...   fk   pk  pkatt season             team target  \
# 1        Tottenham  1.9  ...  1.0  0.0    0.0   2022  Manchester City      0
# 2     Norwich City  2.7  ...  1.0  0.0    0.0   2022  Manchester City      1
# ...

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier(n_estimators=50, min_samples_split=10, random_state=1)

# %%
train = matches[matches["date"] < '2022-01-01']

# %%
test = matches[matches["date"] > '2022-01-01']

# %%
predictors = ["venue_code", "opp_code", "hour", "day_code"]

# %%
rf.fit(train[predictors], train["target"])
# Out:
# RandomForestClassifier(min_samples_split=10, n_estimators=50, random_state=1)

# %%
preds = rf.predict(test[predictors])

# %%
from sklearn.metrics import accuracy_score

# %%
error = accuracy_score(test["target"], preds)

# %%
error
# Out:
# 0.6123188405797102

# %%
combined = pd.DataFrame(dict(actual=test["target"], predicted=preds))

# %%
pd.crosstab(index=combined["actual"], columns=combined["predicted"])
# Out:
# predicted    0   1
# actual
# 0          141  31
# 1           76  28

# %%
from sklearn.metrics import precision_score

precision_score(test["target"], preds)
# Out:
# 0.4745762711864407

# %%
grouped_matches = matches.groupby("team")

# %%
group = grouped_matches.get_group("Manchester City").sort_values("date")

# %%
def rolling_averages(group, cols, new_cols):
    group = group.sort_values("date")
    rolling_stats = group[cols].rolling(3, closed='left').mean()
    group[new_cols] = rolling_stats
    group = group.dropna(subset=new_cols)
    return group

# %%
cols = ["gf", "ga", "sh", "sot", "dist", "fk", "pk", "pkatt"]
new_cols = [f"{c}_rolling" for c in cols]

rolling_averages(group, cols, new_cols)
# Out:
#          date   time         round  day venue result   gf   ga  \
# 5  2020-10-17  17:30   Matchweek 5  Sat  Home      W  1.0  0.0
# 7  2020-10-24  12:30   Matchweek 6  Sat  Away      D  1.0  1.0
# 9  2020-10-31  12:30   Matchweek 7  Sat  Away      W  1.0  0.0
# 11 2020-11-08  16:30   Matchweek 8  Sun  Home      D  1.0  1.0
# 12 2020-11-21  17:30   Matchweek 9  Sat  Away      L  0.0  2.0
# ..        ...    ...           ...  ...   ...    ...  ...  ...
# 42 2022-03-14  20:00  Matchweek 29  Mon  Away      D  0.0  0.0
# 44 2022-04-02  15:00  Matchweek 31  Sat  Away      W  2.0  0.0
# 46 2022-04-10  16:30  Matchweek 32  Sun  Home      D  2.0  2.0
# 49 2022-04-20  20:00  Matchweek 30  Wed  Home      W  3.0  0.0
# 50 2022-04-23  15:00  Matchweek 34  Sat  Home      W  5.0  1.0
#
#           opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 5          Arsenal  1.5  ...    17         5    2.000000   2.333333
# 7         West Ham  1.1  ...    12         5    1.333333   2.000000
# ...

# %%
matches_rolling = matches.groupby("team").apply(lambda x: rolling_averages(x, cols, new_cols))

# %%
matches_rolling
# Out:
#                                  date   time         round  day venue result  \
# team
# Arsenal                 6  2020-10-04  14:00   Matchweek 4  Sun  Home      W
#                         7  2020-10-17  17:30   Matchweek 5  Sat  Away      L
#                         9  2020-10-25  19:15   Matchweek 6  Sun  Home      L
#                         11 2020-11-01  16:30   Matchweek 7  Sun  Away      W
#                         13 2020-11-08  19:15   Matchweek 8  Sun  Home      L
# ...                               ...    ...           ...  ...   ...    ...
# Wolverhampton Wanderers 32 2022-03-13  14:00  Matchweek 29  Sun  Away      W
#                         33 2022-03-18  20:00  Matchweek 30  Fri  Home      L
#                         34 2022-04-02  15:00  Matchweek 31  Sat  Home      W
#                         35 2022-04-08  20:00  Matchweek 32  Fri  Away      L
#                         36 2022-04-24  14:00  Matchweek 34  Sun  Away      L
#
# ...

# %%
matches_rolling = matches_rolling.droplevel('team')

# %%
matches_rolling.head(10)
# Out:
#          date   time         round  day venue result   gf   ga  \
# 6  2020-10-04  14:00   Matchweek 4  Sun  Home      W  2.0  1.0
# 7  2020-10-17  17:30   Matchweek 5  Sat  Away      L  0.0  1.0
# 9  2020-10-25  19:15   Matchweek 6  Sun  Home      L  0.0  1.0
# 11 2020-11-01  16:30   Matchweek 7  Sun  Away      W  1.0  0.0
# 13 2020-11-08  19:15   Matchweek 8  Sun  Home      L  0.0  3.0
# 14 2020-11-22  16:30   Matchweek 9  Sun  Away      D  0.0  0.0
# 16 2020-11-29  19:15  Matchweek 10  Sun  Home      L  1.0  2.0
# 18 2020-12-06  16:30  Matchweek 11  Sun  Away      L  0.0  2.0
# 20 2020-12-13  19:15  Matchweek 12  Sun  Home      L  0.0  1.0
# 21 2020-12-16  18:00  Matchweek 13  Wed  Home      D  1.0  1.0
#
#            opponent   xg  ...  hour  day_code  gf_rolling ga_rolling  \
# 6     Sheffield Utd  0.4  ...    14         6    2.000000   1.333333
# 7   Manchester City  0.9  ...    17         5    1.666667   1.666667
# ...

# %%
matches_rolling.index = range(matches_rolling.shape[0])

# %%
def make_predictions(data, predictors):
    train = data[data["date"] < '2022-01-01']
    test = data[data["date"] > '2022-01-01']
    rf.fit(train[predictors], train["target"])
    preds = rf.predict(test[predictors])
    combined = pd.DataFrame(dict(actual=test["target"], predicted=preds), index=test.index)
    error = precision_score(test["target"], preds)
    return combined, error

# %%
combined, error = make_predictions(matches_rolling, predictors + new_cols)

# %%
error
# Out:
# 0.625

# %%
combined = combined.merge(matches_rolling[["date", "team", "opponent", "result"]], left_index=True, right_index=True)

# %%
combined.head(10)
# Out:
#     actual  predicted       date     team        opponent result
# 55       0          0 2022-01-23  Arsenal         Burnley      D
# 56       1          0 2022-02-10  Arsenal          Wolves      W
# 57       1          0 2022-02-19  Arsenal       Brentford      W
# 58       1          1 2022-02-24  Arsenal          Wolves      W
# 59       1          1 2022-03-06  Arsenal         Watford      W
# 60       1          1 2022-03-13  Arsenal  Leicester City      W
# 61       0          1 2022-03-16  Arsenal       Liverpool      L
# 62       1          0 2022-03-19  Arsenal     Aston Villa      W
# 63       0          0 2022-04-04  Arsenal  Crystal Palace      L
# 64       0          0 2022-04-09  Arsenal        Brighton      L

# %%
class MissingDict(dict):
    __missing__ = lambda self, key: key

map_values = {"Brighton and Hove Albion": "Brighton", "Manchester United": "Manchester Utd", "Newcastle United": "Newcastle Utd", "Tottenham Hotspur": "Tottenham", "West Ham United": "West Ham", "Wolverhampton Wanderers": "Wolves"}
mapping = MissingDict(**map_values)

# %%
combined["new_team"] = combined["team"].map(mapping)

# %%
merged = combined.merge(combined, left_on=["date", "new_team"], right_on=["date", "opponent"])

# %%
merged.shape
merged.head(30)
# Out:
#     actual_x  predicted_x       date       team_x      opponent_x result_x  \
# 0          0            0 2022-01-23      Arsenal         Burnley        D
# 1          1            0 2022-02-10      Arsenal          Wolves        W
# 2          1            0 2022-02-19      Arsenal       Brentford        W
# 3          1            1 2022-02-24      Arsenal          Wolves        W
# 4          1            1 2022-03-06      Arsenal         Watford        W
# 5          1            1 2022-03-13      Arsenal  Leicester City        W
# 6          1            0 2022-03-19      Arsenal     Aston Villa        W
# 7          0            0 2022-04-04      Arsenal  Crystal Palace        L
# 8          0            0 2022-04-09      Arsenal        Brighton        L
# 9          0            0 2022-04-16      Arsenal     Southampton        L
# 10         1            0 2022-04-20      Arsenal         Chelsea        W
# ...

# %%
merged[(merged["predicted_x"] == 1) & (merged["predicted_y"] ==0)]["actual_x"].value_counts()
# Out:
# actual_x
# 1    27
# 0    13
# Name: count, dtype: int64

# %%
# Count wins for each team in 'team_x'
team_x_wins = merged[merged['result_x'] == 'W']['team_x'].value_counts()

# Count wins for each team in 'team_y'
team_y_wins = merged[merged['result_y'] == 'W']['team_y'].value_counts()

# Identify the team with the most wins in 'team_x'
most_wins_team_x = team_x_wins.idxmax()
most_wins_count_x = team_x_wins.max()

# Identify the team with the most wins in 'team_y'
most_wins_team_y = team_y_wins.idxmax()
most_wins_count_y = team_y_wins.max()

print(f"The team with the most wins as 'team_x' is {most_wins_team_x} with {most_wins_count_x} wins.")
print(f"The team with the most wins as 'team_y' is {most_wins_team_y} with {most_wins_count_y} wins.")
# Out:
# The team with the most wins as 'team_x' is Newcastle United with 10 wins.
# The team with the most wins as 'team_y' is Newcastle United with 10 wins.

# %%
results = pd.DataFrame(columns=['Team', 'W', 'D', 'L', 'Points'])

# Calculate results for team_x
team_x_results = merged.groupby('team_x')['result_x'].value_counts().unstack().fillna(0)
team_x_results.columns = [col if col in ['W', 'D', 'L'] else 'Other' for col in team_x_results.columns]
team_x_results = team_x_results[['W', 'D', 'L']]
team_x_results = team_x_results.reset_index().rename(columns={'team_x': 'Team'})

# Calculate results for team_y
team_y_results = merged.groupby('team_y')['result_y'].value_counts().unstack().fillna(0)
team_y_results.columns = [col if col in ['W', 'D', 'L'] else 'Other' for col in team_y_results.columns]
team_y_results = team_y_results[['W', 'D', 'L']]
team_y_results = team_y_results.reset_index().rename(columns={'team_y': 'Team'})

# Combine results
combined_results = pd.concat([team_x_results, team_y_results]).groupby('Team').sum().reset_index()

# Calculate points
combined_results['Points'] = combined_results['W'] * 3 + combined_results['D'] * 1

# Convert columns to integer type
combined_results = combined_results.astype({'W': 'int', 'D': 'int', 'L': 'int', 'Points': 'int'})

# Convert DataFrame to list of dictionaries
results_list = combined_results.to_dict('records')

# Sort the list by 'Points' in descending order
sorted_results_list = sorted(results_list, key=lambda x: x['Points'], reverse=True)

# Convert the sorted list back to DataFrame
sorted_combined_results = pd.DataFrame(sorted_results_list)

# Print the sorted DataFrame without the index
print(sorted_combined_results.to_string(index=False))
# Out:
#                     Team  W  D  L  Points
#         Newcastle United 20  4  6      64
#          Manchester City 16  4  2      52
#                  Arsenal 16  2  6      50
#        Tottenham Hotspur 16  2 12      50
#  Wolverhampton Wanderers 16  0 14      48
#        Manchester United 12 10  8      46
#                  Chelsea 14  2  6      44
#                Brentford 12  4 14      40
#                  Burnley 10 10 12      40
#              Southampton 10  8 12      38
#             Leeds United 10  6 12      36
#          West Ham United 10  6 10      36
# Brighton and Hove Albion  8 10 12      34
#           Leicester City  8 10  8      34
#              Aston Villa  8  6 14      30
#           Crystal Palace  6 12  6      30
#             Norwich City  6  4 16      22
#                  Everton  6  2 20      20
#                  Watford  4  6 18      18
